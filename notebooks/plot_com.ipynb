# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from pathlib import Path

import motorlab as ml

# %%
os.chdir(Path().resolve().parent)

# %%
old_gbyk = True
SESSIONS = ml.sessions.OLD_GBYK if old_gbyk else ml.sessions.GBYK
EXPERIMENT = "old_gbyk" if old_gbyk else "gbyk"
EXPERIMENT_DIR = Path(
    f"data/{EXPERIMENT}" if old_gbyk else f"data/{EXPERIMENT}"
)

# %%
ml.plot.com(Path(f"{EXPERIMENT_DIR}/{SESSIONS[1]}/"), experiment=EXPERIMENT)

# %%
ml.plot.com(
    "data",
    SESSIONS,
    EXPERIMENT,
    ncols=2,
    include_homing=False,
    # save_path="plots/com_trial.svg",
)
# Out:
# old_gbyk
# data/old_gbyk
# data/old_gbyk
# /Users/caio/dev/motorlab/motorlab/poses.py:65: RuntimeWarning: Mean of empty slice
#   com = np.nanmean(com, axis=1)
# data/old_gbyk

# %%
ml.plot.com(
    "../data/gbyk/",
    sessions,
    ncols=2,
    include_homing=True,
    # save_path="plots/com_homing.svg",
)
