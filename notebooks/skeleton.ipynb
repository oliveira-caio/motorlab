# %%
pg_kps = [
    "neck",
    "head",
    "L_ear",
    "R_ear",
    "L_eye",
    "R_eye",
    "nose",
    "L_shoulder",
    "L_elbow",
    "L_wrist",
    "R_shoulder",
    "R_elbow",
    "R_wrist",
    "L_hip",
    "L_knee",
    "L_ankle",
    "R_hip",
    "R_knee",
    "R_ankle",
    "S_tail",
    "E_tail",
]

reduced_pg_kps = [
    "neck",
    "L_ear",
    "R_ear",
    "nose",
    "L_shoulder",
    "L_elbow",
    "L_wrist",
    "R_shoulder",
    "R_elbow",
    "R_wrist",
    "L_hip",
    "L_knee",
    "L_ankle",
    "R_hip",
    "R_knee",
    "R_ankle",
    "S_tail",
    "E_tail",
]

extended_pg_kps = [
    "neck",
    "spine",
    "head",
    "L_ear",
    "R_ear",
    "L_eye",
    "R_eye",
    "nose",
    "L_shoulder",
    "L_elbow",
    "L_wrist",
    "L_upperArm",
    "L_lowerArm",
    "R_shoulder",
    "R_elbow",
    "R_wrist",
    "R_upperArm",
    "R_lowerArm",
    "L_hip",
    "L_knee",
    "L_ankle",
    "L_upperLeg",
    "L_lowerLeg",
    "R_hip",
    "R_knee",
    "R_ankle",
    "R_upperLeg",
    "R_lowerLeg",
    "S_tail",
    "M_tail",
    "E_tail",
]

gbyk_kps = [
    "L_wrist",
    "L_elbow",
    "L_shoulder",
    "R_wrist",
    "R_elbow",
    "R_shoulder",
    "L_ankle",
    "L_knee",
    "L_hip",
    "R_ankle",
    "R_knee",
    "R_hip",
    "E_tail",
    "S_tail",
    "neck",
    "head",
    "L_ear",
    "R_ear",
    "L_eye",
    "R_eye",
    "nose",
]

reduced_gbyk_kps = [
    "L_wrist",
    "L_elbow",
    "L_shoulder",
    "R_wrist",
    "R_elbow",
    "R_shoulder",
    "L_ankle",
    "L_knee",
    "L_hip",
    "R_ankle",
    "R_knee",
    "R_hip",
    "E_tail",
    "S_tail",
    "neck",
    "L_ear",
    "R_ear",
    "nose",
]

new_gbyk_kps = [
    "E_tail",
    "L_ankle",
    "L_ear",
    "L_elbow",
    "L_eye",
    "L_hip",
    "L_knee",
    "L_shoulder",
    "L_wrist",
    "R_ankle",
    "R_ear",
    "R_elbow",
    "R_eye",
    "R_hip",
    "R_knee",
    "R_shoulder",
    "R_wrist",
    "S_tail",
    "head",
    "neck",
    "nose",
]

reduced_new_gbyk_kps = [
    "E_tail",
    "L_ankle",
    "L_ear",
    "L_elbow",
    "L_hip",
    "L_knee",
    "L_shoulder",
    "L_wrist",
    "R_ankle",
    "R_ear",
    "R_elbow",
    "R_hip",
    "R_knee",
    "R_shoulder",
    "R_wrist",
    "S_tail",
    "neck",
    "nose",
]

# %%
skeleton = [
    ["S_tail", "E_tail"],
    ["S_tail", "L_hip"],
    ["S_tail", "R_hip"],
    ["R_knee", "R_hip"],
    ["R_knee", "R_ankle"],
    ["L_knee", "L_hip"],
    ["L_knee", "L_ankle"],
    ["R_elbow", "R_shoulder"],
    ["R_elbow", "R_wrist"],
    ["L_elbow", "L_shoulder"],
    ["L_elbow", "L_wrist"],
    ["neck", "S_tail"],
    ["neck", "head"],
    ["neck", "nose"],
    ["neck", "L_shoulder"],
    ["neck", "R_shoulder"],
    ["neck", "L_ear"],
    ["neck", "R_ear"],
    ["nose", "L_eye"],
    ["nose", "R_eye"],
    ["nose", "L_ear"],
    ["nose", "R_ear"],
    ["head", "L_ear"],
    ["head", "R_ear"],
    ["head", "L_eye"],
    ["head", "R_eye"],
]

reduced_skeleton = [
    ["S_tail", "E_tail"],
    ["S_tail", "L_hip"],
    ["S_tail", "R_hip"],
    ["R_knee", "R_hip"],
    ["R_knee", "R_ankle"],
    ["L_knee", "L_hip"],
    ["L_knee", "L_ankle"],
    ["R_elbow", "R_shoulder"],
    ["R_elbow", "R_wrist"],
    ["L_elbow", "L_shoulder"],
    ["L_elbow", "L_wrist"],
    ["neck", "S_tail"],
    ["neck", "nose"],
    ["neck", "L_shoulder"],
    ["neck", "R_shoulder"],
    ["neck", "L_ear"],
    ["neck", "R_ear"],
    ["nose", "L_ear"],
    ["nose", "R_ear"],
]

extended_skeleton = [
    ["M_tail", "E_tail"],
    ["M_tail", "S_tail"],
    ["S_tail", "spine"],
    ["S_tail", "L_hip"],
    ["S_tail", "R_hip"],
    ["R_upperLeg", "R_hip"],
    ["R_upperLeg", "R_knee"],
    ["R_lowerLeg", "R_knee"],
    ["R_lowerLeg", "R_ankle"],
    ["L_upperLeg", "L_hip"],
    ["L_upperLeg", "L_knee"],
    ["L_lowerLeg", "L_knee"],
    ["L_lowerLeg", "L_ankle"],
    ["R_upperArm", "R_shoulder"],
    ["R_upperArm", "R_elbow"],
    ["R_lowerArm", "R_elbow"],
    ["R_lowerArm", "R_wrist"],
    ["L_upperArm", "L_shoulder"],
    ["L_upperArm", "L_elbow"],
    ["L_lowerArm", "L_elbow"],
    ["L_lowerArm", "L_wrist"],
    ["neck", "spine"],
    ["neck", "head"],
    ["neck", "nose"],
    ["neck", "L_shoulder"],
    ["neck", "R_shoulder"],
    ["neck", "L_ear"],
    ["neck", "R_ear"],
    ["nose", "L_eye"],
    ["nose", "R_eye"],
    ["nose", "L_ear"],
    ["nose", "R_ear"],
    ["head", "L_ear"],
    ["head", "R_ear"],
    ["head", "L_eye"],
    ["head", "R_eye"],
]

# %%
pg_kps2idx = {k: i for i, k in enumerate(pg_kps)}
reduced_pg_kps2idx = {k: i for i, k in enumerate(reduced_pg_kps)}
extended_pg_kps2idx = {k: i for i, k in enumerate(extended_pg_kps)}
gbyk_kps2idx = {k: i for i, k in enumerate(gbyk_kps)}
reduced_gbyk_kps2idx = {k: i for i, k in enumerate(reduced_gbyk_kps)}
new_gbyk_kps2idx = {k: i for i, k in enumerate(new_gbyk_kps)}
reduced_new_gbyk_kps2idx = {k: i for i, k in enumerate(reduced_new_gbyk_kps)}

# %%
print(
    f"Playground Keypoints:\n{pg_kps}\nPlayground Skeleton:\n{sorted([[pg_kps2idx[beg], pg_kps2idx[end]] for beg, end in skeleton])}\n"
)

print(
    f"Reduced Playground Keypoints:\n{reduced_pg_kps}\nReduced Playground Skeleton:\n{sorted([[reduced_pg_kps2idx[beg], reduced_pg_kps2idx[end]] for beg, end in reduced_skeleton])}\n"
)

print(
    f"Extended Playground Keypoints:\n{extended_pg_kps}\nExtended Playground Skeleton:\n{sorted([[extended_pg_kps2idx[beg], extended_pg_kps2idx[end]] for beg, end in extended_skeleton])}\n"
)

print(
    f"GBYK Keypoints:\n{gbyk_kps}\nGBYK Skeleton:\n{sorted([[gbyk_kps2idx[beg], gbyk_kps2idx[end]] for beg, end in skeleton])}\n"
)

print(
    f"Reduced GBYK Keypoints:\n{reduced_gbyk_kps}\nReduced GBYK Skeleton:\n{sorted([[reduced_gbyk_kps2idx[beg], reduced_gbyk_kps2idx[end]] for beg, end in reduced_skeleton])}\n"
)

print(
    f"New GBYK Keypoints:\n{new_gbyk_kps}\nNew GBYK Skeleton:\n{sorted([[new_gbyk_kps2idx[beg], new_gbyk_kps2idx[end]] for beg, end in skeleton])}\n"
)

print(
    f"Reduced New GBYK Keypoints:\n{reduced_new_gbyk_kps}\nReduced New GBYK Skeleton:\n{sorted([[reduced_new_gbyk_kps2idx[beg], reduced_new_gbyk_kps2idx[end]] for beg, end in reduced_skeleton])}\n"
)
# Out:
# Playground Keypoints:
# ['neck', 'head', 'L_ear', 'R_ear', 'L_eye', 'R_eye', 'nose', 'L_shoulder', 'L_elbow', 'L_wrist', 'R_shoulder', 'R_elbow', 'R_wrist', 'L_hip', 'L_knee', 'L_ankle', 'R_hip', 'R_knee', 'R_ankle', 'S_tail', 'E_tail']
# Playground Skeleton:
# [[0, 1], [0, 2], [0, 3], [0, 6], [0, 7], [0, 10], [0, 19], [1, 2], [1, 3], [1, 4], [1, 5], [6, 2], [6, 3], [6, 4], [6, 5], [8, 7], [8, 9], [11, 10], [11, 12], [14, 13], [14, 15], [17, 16], [17, 18], [19, 13], [19, 16], [19, 20]]
#
# Reduced Playground Keypoints:
# ['neck', 'L_ear', 'R_ear', 'nose', 'L_shoulder', 'L_elbow', 'L_wrist', 'R_shoulder', 'R_elbow', 'R_wrist', 'L_hip', 'L_knee', 'L_ankle', 'R_hip', 'R_knee', 'R_ankle', 'S_tail', 'E_tail']
# Reduced Playground Skeleton:
# [[0, 1], [0, 2], [0, 3], [0, 4], [0, 7], [0, 16], [3, 1], [3, 2], [5, 4], [5, 6], [8, 7], [8, 9], [11, 10], [11, 12], [14, 13], [14, 15], [16, 10], [16, 13], [16, 17]]
#
# Extended Playground Keypoints:
# ...
